# %% [markdown]
# <a href="https://colab.research.google.com/github/4d4-developer/-/blob/main/Python_day4_201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/adult_income_dataset.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
age_column = df["age"]
age_column.head()
# Out:
# 0    39
# 1    50
# 2    38
# 3    53
# 4    28
# Name: age, dtype: int64

# %%
df_age = df[df["age"]>= 30]
df_age
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 5       37           Private  284582    Masters             14
# ...    ...               ...     ...        ...            ...
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
# 32557   40           Private  154374    HS-grad              9
# 32558   58           Private  151910    HS-grad              9
# 32560   52      Self-emp-inc  287927    HS-grad              9
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
df_sorted = df.sort_values(by="age")
df_sorted.head()
# Out:
#        age workclass  fnlwgt education  education-num marital-status  \
# 18470   17       NaN   86786      10th              6  Never-married
# 18469   17   Private  104232      10th              6  Never-married
# 32282   17   Private  311907      11th              7  Never-married
# 476     17   Private  211870       9th              5  Never-married
# 25162   17   Private  342752      11th              7  Never-married
#
#           occupation   relationship   race     sex  capital-gain  \
# 18470            NaN      Own-child  White  Female             0
# 18469  Other-service      Own-child  White    Male             0
# 32282  Other-service      Own-child  White    Male             0
# 476    Other-service  Not-in-family  White    Male             0
# 25162  Other-service      Own-child  White    Male             0
#
#        capital-loss  hours-per-week native-country income
# 18470             0              40  United-States  <=50K
# ...
